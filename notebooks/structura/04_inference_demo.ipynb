# %% [markdown]
# # Inference Demo
#
# Loads a fine-tuned checkpoint if provided; otherwise uses the rules baseline.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent.parent
sys.path.insert(0, str(ROOT / 'src'))

from structura.inference import load_generator

generator = load_generator(None)
context = [
    {'id': 'p001', 'type': 'product', 'title': 'Acer Nitro 5', 'category': 'laptop', 'price': 68000, 'features': ['gaming'], 'use_cases': ['gaming', 'study']},
    {'id': 'p002', 'type': 'product', 'title': 'Lenovo IdeaPad 3', 'category': 'laptop', 'price': 52000, 'features': ['office'], 'use_cases': ['study', 'office']},
]
result = generator.generate('Мне нужен ноутбук до 70 тысяч для игр и учебы', context)
result['parsed']
